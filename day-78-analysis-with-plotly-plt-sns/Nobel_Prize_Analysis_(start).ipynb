# %% [markdown]
# # Setup and Context

# %% [markdown]
# ### Introduction
#
# On November 27, 1895, Alfred Nobel signed his last will in Paris. When it was opened after his death, the will caused a lot of controversy, as Nobel had left much of his wealth for the establishment of a prize.
#
# Alfred Nobel dictates that his entire remaining estate should be used to endow “prizes to those who, during the preceding year, have conferred the greatest benefit to humankind”.
#
# Every year the Nobel Prize is given to scientists and scholars in the categories chemistry, literature, physics, physiology or medicine, economics, and peace.
#
# <img src=https://i.imgur.com/36pCx5Q.jpg>
#
# Let's see what patterns we can find in the data of the past Nobel laureates. What can we learn about the Nobel prize and our world more generally?

# %% [markdown]
# ### Upgrade plotly (only Google Colab Notebook)
#
# Google Colab may not be running the latest version of plotly. If you're working in Google Colab, uncomment the line below, run the cell, and restart your notebook server.

# %%
# %pip install --upgrade plotly

# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# ### Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Read the Data

# %%
df_data = pd.read_csv('nobel_prize_data.csv')

# %% [markdown]
# Caveats: The exact birth dates for Michael Houghton, Venkatraman Ramakrishnan, and Nadia Murad are unknown. I've substituted them with mid-year estimate of July 2nd.

# %% [markdown]
# # Data Exploration & Cleaning
#
# **Challenge**: Preliminary data exploration.
# * What is the shape of `df_data`? How many rows and columns?
# * What are the column names?
# * In which year was the Nobel prize first awarded?
# * Which year is the latest year included in the dataset?

# %%
df_data.shape
# Out:
# (962, 16)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   962 non-null    int64
#  1   category               962 non-null    object
#  2   prize                  962 non-null    object
#  3   motivation             874 non-null    object
#  4   prize_share            962 non-null    object
#  5   laureate_type          962 non-null    object
#  6   full_name              962 non-null    object
#  7   birth_date             934 non-null    object
#  8   birth_city             931 non-null    object
#  9   birth_country          934 non-null    object
#  10  birth_country_current  934 non-null    object
#  11  sex                    934 non-null    object
#  12  organization_name      707 non-null    object
#  13  organization_city      707 non-null    object
# ...

# %% [markdown]
# **Challange**:
# * Are there any duplicate values in the dataset?
# * Are there NaN values in the dataset?
# * Which columns tend to have NaN values?
# * How many NaN values are there per column?
# * Why do these columns have NaN values?

# %% [markdown]
# ### Check for Duplicates

# %%
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.isna().sum()
# Out:
# year                       0
# category                   0
# prize                      0
# motivation                88
# prize_share                0
# laureate_type              0
# full_name                  0
# birth_date                28
# birth_city                31
# birth_country             28
# birth_country_current     28
# sex                       28
# organization_name        255
# organization_city        255
# organization_country     254
# ISO                       28
# dtype: int64

# %% [markdown]
# ### Check for NaN Values

# %% [markdown]
# ### Type Conversions
#
# **Challenge**:
# * Convert the `birth_date` column to Pandas `Datetime` objects
# * Add a Column called `share_pct` which has the laureates' share as a percentage in the form of a floating-point number.

# %% [markdown]
# #### Convert Year and Birth Date to Datetime

# %%
df_data["birth_date"] = pd.to_datetime(df_data["birth_date"])

# %% [markdown]
# #### Add a Column with the Prize Share as a Percentage

# %%
df_data["share_pct"] = df_data["prize_share"].apply(lambda x: int(x.split("/")[0]) / int(x.split("/")[1]))

# %%
df_data.sample(5)
# Out:
#      year   category                                              prize  \
# 194  1937      Peace                         The Nobel Peace Prize 1937
# 253  1950   Medicine     The Nobel Prize in Physiology or Medicine 1950
# 429  1973  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 787  2006   Medicine     The Nobel Prize in Physiology or Medicine 2006
# 681  1997   Medicine     The Nobel Prize in Physiology or Medicine 1997
#
#                                             motivation prize_share  \
# 194                                                NaN         1/1
# 253  "for their discoveries relating to the hormone...         1/3
# 429  "for the development of the input-output metho...         1/1
# 787  "for their discovery of RNA interference - gen...         1/2
# 681  "for his discovery of Prions - a new biologica...         1/1
#
#     laureate_type                                          full_name  \
# ...

# %% [markdown]
# # Plotly Donut Chart: Percentage of Male vs. Female Laureates

# %% [markdown]
# **Challenge**: Create a [donut chart using plotly](https://plotly.com/python/pie-charts/) which shows how many prizes went to men compared to how many prizes went to women. What percentage of all the prizes went to women?

# %%
male_vs_female = df_data["sex"].value_counts()

# %%
male_vs_female = pd.DataFrame(male_vs_female)

# %%
male_vs_female
# Out:
#         count
# sex
# Male      876
# Female     58

# %%
pie = px.pie(
    data_frame=male_vs_female,
    names=male_vs_female.index,
    values="count",
    title="Percentage of Male vs. Female Winners",
    labels=male_vs_female.index,
    hole=0.6
)

pie.update_traces(textposition="inside", textinfo="percent")
pie.show()

# %% [markdown]
# # Who were the first 3 Women to Win the Nobel Prize?
#
# **Challenge**:
# * What are the names of the first 3 female Nobel laureates?
# * What did the win the prize for?
# * What do you see in their `birth_country`? Were they part of an organisation?

# %%
df_data["sex"].value_counts()
# Out:
# sex
# Male      876
# Female     58
# Name: count, dtype: int64

# %%
df_data[df_data["sex"] == "Female"].sort_values("year").head(5)
# Out:
#      year    category                               prize  \
# 18   1903     Physics     The Nobel Prize in Physics 1903
# 29   1905       Peace          The Nobel Peace Prize 1905
# 51   1909  Literature  The Nobel Prize in Literature 1909
# 62   1911   Chemistry   The Nobel Prize in Chemistry 1911
# 128  1926  Literature  The Nobel Prize in Literature 1926
#
#                                             motivation prize_share  \
# 18   "in recognition of the extraordinary services ...         1/4
# 29                                                 NaN         1/1
# 51   "in appreciation of the lofty idealism, vivid ...         1/1
# 62   "in recognition of her services to the advance...         1/1
# 128  "for her idealistically inspired writings whic...         1/1
#
#     laureate_type                                          full_name  \
# 18     Individual                        Marie Curie, née Sklodowska
# 29     Individual  Baroness Bertha Sophie Felicita von Suttner, n...
# ...

# %% [markdown]
# # Find the Repeat Winners
#
# **Challenge**: Did some people get a Nobel Prize more than once? If so, who were they?

# %%
df_data["full_name"].value_counts().sort_values()
# Out:
# full_name
# Françoise Barré-Sinoussi                                                             1
# Philipp Eduard Anton von Lenard                                                      1
# Karl Manne Georg Siegbahn                                                            1
# Bjørnstjerne Martinus Bjørnson                                                       1
# Emil Adolf von Behring                                                               1
#                                                                                     ..
# Office of the United Nations High Commissioner for Refugees (UNHCR)                  2
# John Bardeen                                                                         2
# Linus Carl Pauling                                                                   2
# Frederick Sanger                                                                     2
# Comité international de la Croix Rouge (International Committee of the Red Cross)    3
# ...

# %%
df_data[df_data.duplicated(subset=["full_name"], keep=False)]
# Out:
#      year   category                              prize  \
# 18   1903    Physics    The Nobel Prize in Physics 1903
# 62   1911  Chemistry  The Nobel Prize in Chemistry 1911
# 89   1917      Peace         The Nobel Peace Prize 1917
# 215  1944      Peace         The Nobel Peace Prize 1944
# 278  1954  Chemistry  The Nobel Prize in Chemistry 1954
# 283  1954      Peace         The Nobel Peace Prize 1954
# 297  1956    Physics    The Nobel Prize in Physics 1956
# 306  1958  Chemistry  The Nobel Prize in Chemistry 1958
# 340  1962      Peace         The Nobel Peace Prize 1962
# 348  1963      Peace         The Nobel Peace Prize 1963
# 424  1972    Physics    The Nobel Prize in Physics 1972
# 505  1980  Chemistry  The Nobel Prize in Chemistry 1980
# 523  1981      Peace         The Nobel Peace Prize 1981
#
#                                             motivation prize_share  \
# 18   "in recognition of the extraordinary services ...         1/4
# ...

# %% [markdown]
# # Number of Prizes per Category
#
# **Challenge**:
# * In how many categories are prizes awarded?
# * Create a plotly bar chart with the number of prizes awarded by category.
# * Use the color scale called `Aggrnyl` to colour the chart, but don't show a color axis.
# * Which category has the most number of prizes awarded?
# * Which category has the fewest number of prizes awarded?

# %%
df_data["category"].nunique()
# Out:
# 6

# %%
category_count = df_data["category"].value_counts()
category_count = pd.DataFrame(category_count)
category_count
# Out:
#             count
# category
# Medicine      222
# Physics       216
# Chemistry     186
# Peace         135
# Literature    117
# Economics      86

# %%
bar = px.bar(
    data_frame=category_count,
    x=category_count.index,
    y="count",
    color="count",
    color_continuous_scale="Aggrnyl",
    title="Number of Nobel Prize Winners by Category",
)

bar.update_layout(
    xaxis_title="Category",
    coloraxis_showscale=False,
    yaxis_title="Number of Winners"
)

bar.show()

# %% [markdown]
# **Challenge**:
# * When was the first prize in the field of Economics awarded?
# * Who did the prize go to?

# %%
df_data[df_data["category"] == "Economics"].sort_values("year").head()
# Out:
#      year   category                                              prize  \
# 393  1969  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 394  1969  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 402  1970  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 411  1971  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 419  1972  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# 393  "for having developed and applied dynamic mode...         1/2
# 394  "for having developed and applied dynamic mode...         1/2
# 402  "for the scientific work through which he has ...         1/1
# 411  "for his empirically founded interpretation of...         1/1
# 419  "for their pioneering contributions to general...         1/2
#
#     laureate_type          full_name birth_date birth_city  \
# 393    Individual      Jan Tinbergen 1903-04-12  the Hague
# ...

# %%
df_data[df_data["category"] == "Physics"].sort_values("year").head()
# Out:
#     year category                            prize  \
# 5   1901  Physics  The Nobel Prize in Physics 1901
# 11  1902  Physics  The Nobel Prize in Physics 1902
# 12  1902  Physics  The Nobel Prize in Physics 1902
# 17  1903  Physics  The Nobel Prize in Physics 1903
# 18  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            motivation prize_share  \
# 5   "in recognition of the extraordinary services ...         1/1
# 11  "in recognition of the extraordinary service t...         1/2
# 12  "in recognition of the extraordinary service t...         1/2
# 17  "in recognition of the extraordinary services ...         1/2
# 18  "in recognition of the extraordinary services ...         1/4
#
#    laureate_type                    full_name birth_date          birth_city  \
# 5     Individual       Wilhelm Conrad Röntgen 1845-03-27  Lennep (Remscheid)
# 11    Individual       Hendrik Antoon Lorentz 1853-07-18              Arnhem
# ...

# %% [markdown]
# # Male and Female Winners by Category
#
# **Challenge**: Create a [plotly bar chart](https://plotly.com/python/bar-charts/) that shows the split between men and women by category.
# * Hover over the bar chart. How many prizes went to women in Literature compared to Physics?
#
# <img src=https://i.imgur.com/od8TfOp.png width=650>

# %%
category_sex_count = df_data.groupby(["category", "sex"], as_index=False).agg({"year": pd.Series.count})
category_sex_count.columns = ["category", "sex", "count"]
category_sex_count.sort_values("count", ascending=False, inplace=True)

# %%
type(category_sex_count)
# Out:
# pandas.core.frame.DataFrame

# %%
v_bar_split = px.bar(
    x = category_sex_count.category,
    y = category_sex_count["count"],
    color = category_sex_count.sex,
    title="Number of Prizes Awarded per Category split by Men and Women",
)

v_bar_split.update_layout(
    xaxis_title="Category",
    yaxis_title="Number of Prizes Awarded",
)

v_bar_split.show()

# %% [markdown]
# # Number of Prizes Awarded Over Time
#
# **Challenge**: Are more prizes awarded recently than when the prize was first created? Show the trend in awards visually.
# * Count the number of prizes awarded every year.
# * Create a 5 year rolling average of the number of prizes (Hint: see previous lessons analysing Google Trends).
# * Using Matplotlib superimpose the rolling average on a scatter plot.
# * Show a tick mark on the x-axis for every 5 years from 1900 to 2020. (Hint: you'll need to use NumPy).
#
# <img src=https://i.imgur.com/4jqYuWC.png width=650>
#
# * Use the [named colours](https://matplotlib.org/3.1.0/gallery/color/named_colors.html) to draw the data points in `dogerblue` while the rolling average is coloured in `crimson`.
#
# <img src=https://i.imgur.com/u3RlcJn.png width=350>
#
# * Looking at the chart, did the first and second world wars have an impact on the number of prizes being given out?
# * What could be the reason for the trend in the chart?

# %%
prize_per_year = df_data["year"].value_counts().sort_index()
prize_per_year = pd.DataFrame(prize_per_year)
prize_per_year
# Out:
#       count
# year
# 1901      6
# 1902      7
# 1903      7
# 1904      6
# 1905      5
# ...     ...
# 2016     11
# 2017     12
# 2018     13
# 2019     14
# 2020     12
#
# [117 rows x 1 columns]

# %%
prize_per_year = pd.DataFrame({"year": prize_per_year.index, "count": prize_per_year["count"]})
prize_per_year
# Out:
#       year  count
# year
# 1901  1901      6
# 1902  1902      7
# 1903  1903      7
# 1904  1904      6
# 1905  1905      5
# ...    ...    ...
# 2016  2016     11
# 2017  2017     12
# 2018  2018     13
# 2019  2019     14
# 2020  2020     12
#
# [117 rows x 2 columns]

# %%
type(prize_per_year.iloc[0, 0])
# Out:
# numpy.int64

# %%
fig = px.line(
    x=prize_per_year.year,
    y=prize_per_year["count"].rolling(3).mean(),
)

fig.show()

# %%
moving_average = prize_per_year["count"].rolling(5).mean()

plt.figure(figsize=(16, 8), dpi=200)
plt.title("Number of Nobel Prizes Awarded per Year", fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(ticks=np.arange(1990, 2021, step=5), fontsize=15, rotation=45)

ax = plt.gca()
ax.set_xlim(1900, 2020)

ax.scatter(
    x=prize_per_year.index,
    y=prize_per_year["count"],
    c="dodgerblue",
    alpha=0.7,
    s=100
)

ax.plot(
    prize_per_year.index,
    moving_average,
    c="crimson",
    linewidth=3
)

plt.show()

# %% [markdown]
# # Are More Prizes Shared Than Before?
#
# **Challenge**: Investigate if more prizes are shared than before.
#
# * Calculate the average prize share of the winners on a year by year basis.
# * Calculate the 5 year rolling average of the percentage share.
# * Copy-paste the cell from the chart you created above.
# * Modify the code to add a secondary axis to your Matplotlib chart.
# * Plot the rolling average of the prize share on this chart.
# * See if you can invert the secondary y-axis to make the relationship even more clear.

# %%
prize_share_per_year = df_data.groupby("year").agg({"share_pct": pd.Series.mean})

# %%
prize_share_per_year
# Out:
#       share_pct
# year
# 1901       0.83
# 1902       0.71
# 1903       0.71
# 1904       0.83
# 1905       1.00
# ...         ...
# 2016       0.55
# 2017       0.50
# 2018       0.46
# 2019       0.43
# 2020       0.50
#
# [117 rows x 1 columns]

# %%
from plotly.subplots import make_subplots

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Line(
    x=prize_share_per_year.index,
    y=prize_share_per_year["share_pct"].rolling(5).mean(),
    name="Average Share of Prize per Year"
    ), 
    secondary_y=False,)

fig.add_trace(go.Line(
    x=prize_per_year.year,
    y=prize_per_year["count"].rolling(3).mean(),
    name="Average Number of Prizes per Year"
    ), 
    secondary_y=True,)

fig.update_layout(
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=0.01
    ))
fig.show()
# Out:
# /opt/miniconda3/envs/udemy/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
yearly_avg_share = df_data.groupby("year").agg({"share_pct": pd.Series.mean})
share_moving_average = yearly_avg_share.rolling(5).mean()

# %%
plt.figure(figsize=(16, 8), dpi=200)
plt.title("Number of Nobel Prize per Year", fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(ticks=np.arange(1900, 2021, step=5), fontsize=15, rotation=45)
ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.set_xlim(1900, 2020)

ax1.scatter(
    x=prize_per_year.index,
    y=prize_per_year["count"],
    c="dodgerblue",
    alpha=0.7,
    s=100
)

ax1.plot(
    prize_per_year.index,
    moving_average,
    c="crimson",
    linewidth=3
)

ax2.plot(prize_per_year.index, share_moving_average, c="black", linewidth=3)

plt.show()

# %% [markdown]
# # The Countries with the Most Nobel Prizes

# %% [markdown]
# **Challenge**:
# * Create a Pandas DataFrame called `top20_countries` that has the two columns. The `prize` column should contain the total number of prizes won.
#
# <img src=https://i.imgur.com/6HM8rfB.png width=350>
#
# * Is it best to use `birth_country`, `birth_country_current` or `organization_country`?
# * What are some potential problems when using `birth_country` or any of the others? Which column is the least problematic?
# * Then use plotly to create a horizontal bar chart showing the number of prizes won by each country. Here's what you're after:
#
# <img src=https://i.imgur.com/agcJdRS.png width=750>
#
# * What is the ranking for the top 20 countries in terms of the number of prizes?

# %%
top20_countries = df_data["birth_country_current"].value_counts().sort_values(ascending=False).head(20)
top20_countries.head()
# Out:
# birth_country_current
# United States of America    281
# United Kingdom              105
# Germany                      84
# France                       57
# Sweden                       29
# Name: count, dtype: int64

# %%
df_data[["birth_country", "birth_country_current", "organization_country"]].isna().sum()
# Out:
# birth_country             28
# birth_country_current     28
# organization_country     254
# dtype: int64

# %%
top20_countries = top20_countries.sort_values(ascending=True)

# %%
h_bar = px.bar(
    y=top20_countries.index,
    x=top20_countries.values,
    title="Top 20 Countries with the Most Nobel Prize Winners",
    orientation="h",
    color=top20_countries.values,
    color_continuous_scale="Viridis",
)

h_bar.update_layout(xaxis_title='Number of Prizes', 
                    yaxis_title='Country',
                    coloraxis_showscale=False,
                    yaxis={"dtick": 1}
                    )

h_bar.show()

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Prizes Won by Country
#
# * Create this choropleth map using [the plotly documentation](https://plotly.com/python/choropleth-maps/):
#
# <img src=https://i.imgur.com/s4lqYZH.png>
#
# * Experiment with [plotly's available colours](https://plotly.com/python/builtin-colorscales/). I quite like the sequential colour `matter` on this map.
#
# Hint: You'll need to use a 3 letter country code for each country.

# %%
df
# Out:
#                  country continent  year  lifeExp       pop  gdpPercap  \
# 11           Afghanistan      Asia  2007    43.83  31889923     974.58
# 23               Albania    Europe  2007    76.42   3600523   5,937.03
# 35               Algeria    Africa  2007    72.30  33333216   6,223.37
# 47                Angola    Africa  2007    42.73  12420476   4,797.23
# 59             Argentina  Americas  2007    75.32  40301927  12,779.38
# ...                  ...       ...   ...      ...       ...        ...
# 1655             Vietnam      Asia  2007    74.25  85262356   2,441.58
# 1667  West Bank and Gaza      Asia  2007    73.42   4018332   3,025.35
# 1679         Yemen, Rep.      Asia  2007    62.70  22211743   2,280.77
# 1691              Zambia    Africa  2007    42.38  11746035   1,271.21
# 1703            Zimbabwe    Africa  2007    43.49  12311143     469.71
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# 35         DZA       12
# ...

# %%
prize_per_country = df_data.ISO.value_counts()
prize_per_country = pd.DataFrame({"iso_alpha": prize_per_country.index, "count": prize_per_country.values})

# %%
df = px.data.gapminder().query("year==2007")
fig = px.choropleth(prize_per_country, locations="iso_alpha",
                    color="count", # lifeExp is a column of gapminder
                    hover_name="count", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()

# %%
df = px.data.gapminder().query("year==2007")
fig = px.choropleth(df, locations="iso_alpha",
                    color="lifeExp", # lifeExp is a column of gapminder
                    hover_name="country", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()

# %%
df_countries = df_data.groupby(
    ["birth_country_current", "ISO"], as_index=False
).agg({
    "prize": pd.Series.count,
})

df_countries.sort_values("prize", ascending=False)
# Out:
#        birth_country_current  ISO  prize
# 74  United States of America  USA    281
# 73            United Kingdom  GBR    105
# 26                   Germany  DEU     84
# 25                    France  FRA     57
# 67                    Sweden  SWE     29
# ..                       ...  ...    ...
# 32                   Iceland  ISL      1
# 47                Madagascar  MDG      1
# 34                 Indonesia  IDN      1
# 36                      Iraq  IRQ      1
# 78                  Zimbabwe  ZWE      1
#
# [79 rows x 3 columns]

# %%
world_map = px.choropleth(
    df_countries,
    locations="ISO",
    color="prize",
    hover_name="birth_country_current",
    color_continuous_scale=px.colors.sequential.matter 
)

world_map.update_layout(
    coloraxis_showscale=True 
)

world_map.show()

# %% [markdown]
# # In Which Categories are the Different Countries Winning Prizes?
#
# **Challenge**: See if you can divide up the plotly bar chart you created above to show the which categories made up the total number of prizes. Here's what you're aiming for:
#
# <img src=https://i.imgur.com/iGaIKCL.png>
#
# * In which category are Germany and Japan the weakest compared to the United States?
# * In which category does Germany have more prizes than the UK?
# * In which categories does France have more prizes than Germany?
# * Which category makes up most of Australia's nobel prizes?
# * Which category makes up half of the prizes in the Netherlands?
# * Does the United States have more prizes in Economics than all of France? What about in Physics or Medicine?
#
#
# The hard part is preparing the data for this chart!
#
#
# *Hint*: Take a two-step approach. The first step is grouping the data by country and category. Then you can create a DataFrame that looks something like this:
#
# <img src=https://i.imgur.com/VKjzKa1.png width=450>

# %%
df_data.head(3)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...         1/1
# 1  "in special recognition of his poetic composit...         1/1
# 2  "for his work on serum therapy, especially its...         1/1
#
#   laureate_type                     full_name birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme 1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
#
#       birth_country birth_country_current   sex   organization_name  \
# ...

# %%
prize_per_country_category = df_data.groupby(["birth_country", "category"], as_index=False).agg({"prize": pd.Series.count})
prize_per_country_category.head()
# Out:
#   birth_country   category  prize
# 0     Argentina   Medicine      2
# 1     Argentina      Peace      2
# 2     Australia  Chemistry      1
# 3     Australia   Medicine      7
# 4     Australia    Physics      2

# %%
tmp = prize_per_country_category.groupby("birth_country").agg({"prize": pd.Series.sum}).sort_values("prize", ascending=False).head(10)
prize_per_country_category = pd.merge(prize_per_country_category, tmp, on="birth_country", how="inner")
prize_per_country_category.columns = ["birth_country", "category", "category_prize", "total_prize"]
prize_per_country_category["category_prize_pct"] = prize_per_country_category["category_prize"] / prize_per_country_category["total_prize"]
prize_per_country_category = prize_per_country_category.sort_values("total_prize", ascending=False).head(20)

# %%
bar = px.bar(
    data_frame=prize_per_country_category,
    x="birth_country",
    y="category_prize",
    color="category",
)

bar.show()

# %%
cat_country = df_data.groupby(
    ["birth_country_current", "category"], as_index=False
).agg({"prize": pd.Series.count})
cat_country.sort_values("prize", ascending=False, inplace=True)
cat_country
# Out:
#         birth_country_current   category  prize
# 204  United States of America   Medicine     78
# 206  United States of America    Physics     70
# 201  United States of America  Chemistry     55
# 202  United States of America  Economics     49
# 198            United Kingdom   Medicine     28
# ..                        ...        ...    ...
# 97                       Iraq      Peace      1
# 99                    Ireland   Medicine      1
# 100                   Ireland    Physics      1
# 102                    Israel  Economics      1
# 210                  Zimbabwe      Peace      1
#
# [211 rows x 3 columns]

# %%
merged_df = pd.merge(cat_country, top20_countries, on="birth_country_current", how="inner")
merged_df.columns = ["birth_country_current", "category", "cat_prize", "total_prize"]
merged_df.sort_values(by="total_prize", inplace=True)
merged_df
# Out:
#         birth_country_current    category  cat_prize  total_prize
# 91               South Africa   Chemistry          1            9
# 88               South Africa       Peace          3            9
# 89               South Africa    Medicine          3            9
# 90               South Africa  Literature          2            9
# 101                   Hungary  Literature          1            9
# ..                        ...         ...        ...          ...
# 4    United States of America       Peace         19          281
# 3    United States of America   Economics         49          281
# 2    United States of America   Chemistry         55          281
# 1    United States of America     Physics         70          281
# 0    United States of America    Medicine         78          281
#
# [108 rows x 4 columns]

# %%
cat_cntry_bar = px.bar(
    x=merged_df.cat_prize,
    y=merged_df.birth_country_current,
    color=merged_df.category,
    orientation="h",
    title="Top 20 Countries with the Most Nobel Prize Winners by Category",
)

cat_cntry_bar.update_layout(
    xaxis_title="Number of Prizes",
    yaxis_title="Country",
    yaxis={"dtick": 1}
)

cat_cntry_bar.show()

# %% [markdown]
# ### Number of Prizes Won by Each Country Over Time
#
# * When did the United States eclipse every other country in terms of the number of prizes won?
# * Which country or countries were leading previously?
# * Calculate the cumulative number of prizes won by each country in every year. Again, use the `birth_country_current` of the winner to calculate this.
# * Create a [plotly line chart](https://plotly.com/python/line-charts/) where each country is a coloured line.

# %%
prize_per_year_per_country = df_data.groupby(["birth_country_current", "year"], as_index=False).agg({"prize": pd.Series.count}).sort_values("year", ascending=True)

# %%
prize_per_year_per_country = pd.merge(prize_per_year_per_country, top20_countries, on="birth_country_current", how="inner")

# %%
prize_per_year_per_country.head()
# Out:
#   birth_country_current  year  prize  count
# 0                France  1901      2     57
# 1                France  1903      2     57
# 2                France  1904      1     57
# 3                France  1906      1     57
# 4                France  1907      2     57

# %%
cumulative_prizes = prize_per_year_per_country.groupby(
    ["birth_country_current", "year"]
).sum().groupby(level=[0]).cumsum()
cumulative_prizes.reset_index(inplace=True)
cumulative_prizes
# Out:
#         birth_country_current  year  prize  count
# 0                   Australia  1915      1     10
# 1                   Australia  1945      2     20
# 2                   Australia  1960      3     30
# 3                   Australia  1963      4     40
# 4                   Australia  1964      5     50
# ..                        ...   ...    ...    ...
# 494  United States of America  2016    259  23885
# 495  United States of America  2017    265  24166
# 496  United States of America  2018    271  24447
# 497  United States of America  2019    274  24728
# 498  United States of America  2020    281  25009
#
# [499 rows x 4 columns]

# %%
fig = px.line(
    cumulative_prizes,
    x="year", y="prize", 
    color="birth_country_current",
    hover_name="birth_country_current",)

fig.show()

# %% [markdown]
# # What are the Top Research Organisations?
#
# **Challenge**: Create a bar chart showing the organisations affiliated with the Nobel laureates. It should looks something like this:
#
# <img src=https://i.imgur.com/zZihj2p.png width=600>
#
# * Which organisations make up the top 20?
# * How many Nobel prize winners are affiliated with the University of Chicago and Harvard University?

# %%
df_data.head(3)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...         1/1
# 1  "in special recognition of his poetic composit...         1/1
# 2  "for his work on serum therapy, especially its...         1/1
#
#   laureate_type                     full_name birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme 1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
#
#       birth_country birth_country_current   sex   organization_name  \
# ...

# %%
top20_organizations = df_data.groupby("organization_name").agg({"prize": pd.Series.count}).sort_values("prize", ascending=False).head(20)

# %%
top20_organizations = top20_organizations.sort_values("prize", ascending=True)
top20_organizations
# Out:
#                                               prize
# organization_name
# University College London                         7
# Sorbonne University                               7
# London University                                 7
# Harvard Medical School                            7
# Bell Laboratories                                 8
# Cornell University                                8
# Yale University                                   9
# MRC Laboratory of Molecular Biology              10
# University of Oxford                             12
# Max-Planck-Institut                              13
# Rockefeller University                           13
# Princeton University                             15
# Columbia University                              17
# California Institute of Technology (Caltech)     17
# University of Cambridge                          18
# University of Chicago                            20
# Massachusetts Institute of Technology (MIT)      21
# ...

# %%
h_bar = px.bar(
    y=top20_organizations.index,
    x=top20_organizations.prize,
    title="Top 20 Organizations with the Most Nobel Prize Winners",
    orientation="h",
    color=top20_organizations.prize,
    color_continuous_scale="Viridis",
)

h_bar.update_layout(xaxis_title='Organization',
                    yaxis_title='Number of Prizes',
                    yaxis={"dtick": 1},
)

h_bar.show()

# %% [markdown]
# # Which Cities Make the Most Discoveries?
#
# Where do major discoveries take place?
#
# **Challenge**:
# * Create another plotly bar chart graphing the top 20 organisation cities of the research institutions associated with a Nobel laureate.
# * Where is the number one hotspot for discoveries in the world?
# * Which city in Europe has had the most discoveries?

# %%
top20_cities = df_data.groupby("organization_city").agg({"prize": pd.Series.count}).sort_values("prize", ascending=False).head(20)

# %%
top20_cities = top20_cities.sort_values("prize", ascending=True)

# %%
h_bar = px.bar(
    y=top20_cities.index,
    x=top20_cities.prize,
    title="Top 20 Cities with the Most Nobel Prize Winners",
    orientation="h",
    color=top20_cities.prize,
    color_continuous_scale=px.colors.sequential.Plasma,

)

h_bar.update_layout(xaxis_title='City',
                    yaxis_title='Number of Prizes',
                    yaxis={"dtick": 1},
)

h_bar.show()

# %% [markdown]
# # Where are Nobel Laureates Born? Chart the Laureate Birth Cities
#
# **Challenge**:
# * Create a plotly bar chart graphing the top 20 birth cities of Nobel laureates.
# * Use a named colour scale called `Plasma` for the chart.
# * What percentage of the United States prizes came from Nobel laureates born in New York?
# * How many Nobel laureates were born in London, Paris and Vienna?
# * Out of the top 5 cities, how many are in the United States?

# %%
df_data.head(3)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...         1/1
# 1  "in special recognition of his poetic composit...         1/1
# 2  "for his work on serum therapy, especially its...         1/1
#
#   laureate_type                     full_name birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme 1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
#
#       birth_country birth_country_current   sex   organization_name  \
# ...

# %%
top20_birth_cities = df_data.groupby("birth_city").agg({"prize": pd.Series.count}).sort_values("prize", ascending=False).head(20)
top20_birth_cities.sort_values("prize", ascending=True, inplace=True)

# %%
top20_birth_cities
# Out:
#                        prize
# birth_city
# Cambridge, MA              3
# Montreal                   4
# Pittsburgh, PA             4
# Cairo                      4
# Frankfurt-on-the-Main      5
# Prague                     5
# Hamburg                    6
# Stockholm                  6
# Moscow                     7
# Munich                     7
# Boston, MA                 8
# Brooklyn, NY               8
# Washington, DC             8
# Budapest                   8
# Berlin                    11
# Chicago, IL               12
# Vienna                    14
# London                    19
# Paris                     26
# New York, NY              53

# %%
h_bar = px.bar(
    y=top20_birth_cities.index,
    x=top20_birth_cities.prize,
    title="Top 20 Birth Cities with the Most Nobel Prize Winners",
    orientation="h",
    color=top20_birth_cities.prize,
    color_continuous_scale="Viridis",
)

h_bar.update_layout(xaxis_title='City',
                    yaxis_title='Number of Prizes',
                    yaxis={"dtick": 1},
)

h_bar.show()

# %% [markdown]
# # Plotly Sunburst Chart: Combine Country, City, and Organisation
#
# **Challenge**:
#
# * Create a DataFrame that groups the number of prizes by organisation.
# * Then use the [plotly documentation to create a sunburst chart](https://plotly.com/python/sunburst-charts/)
# * Click around in your chart, what do you notice about Germany and France?
#
#
# Here's what you're aiming for:
#
# <img src=https://i.imgur.com/cemX4m5.png width=300>

# %%
df_data.head(3)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...         1/1
# 1  "in special recognition of his poetic composit...         1/1
# 2  "for his work on serum therapy, especially its...         1/1
#
#   laureate_type                     full_name birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme 1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
#
#       birth_country birth_country_current   sex   organization_name  \
# ...

# %%
df_org_country = df_data.groupby("organization_country").agg({"prize": pd.Series.count}).sort_values("prize", ascending=False)

# %%
fig = px.sunburst(
    df_org_country,
    names=df_org_country.index,
    parents=[""] * len(df_org_country.index),
    values=df_org_country.prize,
)

fig.show()

# %%
country_city_org = df_data.groupby(
    ["organization_country", "organization_city", "organization_name"], 
    as_index=False
    ).agg({"prize": pd.Series.count})
country_city_org = country_city_org.sort_values("prize", ascending=False)

# %%
country_city_org.head()
# Out:
#          organization_country organization_city  \
# 205  United States of America     Cambridge, MA
# 280  United States of America      Stanford, CA
# 206  United States of America     Cambridge, MA
# 209  United States of America       Chicago, IL
# 195  United States of America      Berkeley, CA
#
#                                organization_name  prize
# 205                           Harvard University     29
# 280                          Stanford University     23
# 206  Massachusetts Institute of Technology (MIT)     21
# 209                        University of Chicago     20
# 195                     University of California     19

# %%
burst = px.sunburst(
    country_city_org,
    path=["organization_country", "organization_city", "organization_name"],
    values="prize",
    title="Where do discoveries happen?",
)

burst.update_layout(
    xaxis_title="Organization Country",
    yaxis_title="Organization City",
    coloraxis_showscale=False,
)

burst.show()

# %% [markdown]
# # Patterns in the Laureate Age at the Time of the Award
#
# How Old Are the Laureates When the Win the Prize?
#
# **Challenge**: Calculate the age of the laureate in the year of the ceremony and add this as a column called `winning_age` to the `df_data` DataFrame. Hint: you can use [this](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to help you.

# %%
df_data.head(3)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...         1/1
# 1  "in special recognition of his poetic composit...         1/1
# 2  "for his work on serum therapy, especially its...         1/1
#
#   laureate_type                     full_name birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme 1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
#
#       birth_country birth_country_current   sex   organization_name  \
# ...

# %%
# Out:
# 0     1901-01-01
# 1     1901-01-01
# 2     1901-01-01
# 3     1901-01-01
# 4     1901-01-01
#          ...
# 957   2020-01-01
# 958   2020-01-01
# 959   2020-01-01
# 960   2020-01-01
# 961   2020-01-01
# Name: year, Length: 962, dtype: datetime64[ns]

# %%
(pd.to_datetime(df_data.year.apply(lambda x: str(x) + "-01-01")) - df_data.birth_date).dt.days / 365
# Out:
# 0     48.37
# 1     61.84
# 2     46.83
# 3     78.67
# 4     72.70
#        ...
# 957   70.55
# 958     NaN
# 959   54.58
# 960   67.82
# 961   88.46
# Length: 962, dtype: float64

# %%
winning_age = ((pd.to_datetime(df_data.year.apply(lambda x: str(x) + "-01-01")) - df_data.birth_date).dt.days / 365).fillna(0).astype(int)
df_data["winning_age"] = winning_age

# %%
df_data.head(3)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...         1/1
# 1  "in special recognition of his poetic composit...         1/1
# 2  "for his work on serum therapy, especially its...         1/1
#
#   laureate_type                     full_name birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme 1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
#
#       birth_country birth_country_current   sex   organization_name  \
# ...

# %%
df_data.sort_values("winning_age", ascending=False).head(10)
# Out:
#      year    category                                              prize  \
# 937  2019   Chemistry                  The Nobel Prize in Chemistry 2019
# 933  2018     Physics                    The Nobel Prize in Physics 2018
# 794  2007   Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 961  2020     Physics                    The Nobel Prize in Physics 2020
# 856  2012   Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 815  2008     Physics                    The Nobel Prize in Physics 2008
# 796  2007  Literature                 The Nobel Prize in Literature 2007
# 745  2002     Physics                    The Nobel Prize in Physics 2002
# 374  1966    Medicine     The Nobel Prize in Physiology or Medicine 1966
# 658  1995       Peace                         The Nobel Peace Prize 1995
#
#                                             motivation prize_share  \
# 937     “for the development of lithium-ion batteries”         1/3
# ...

# %%
df_data.sort_values("winning_age", ascending=True).head(10)
# Out:
#      year category                       prize  \
# 788  2006    Peace  The Nobel Peace Prize 2006
# 24   1904    Peace  The Nobel Peace Prize 1904
# 215  1944    Peace  The Nobel Peace Prize 1944
# 479  1977    Peace  The Nobel Peace Prize 1977
# 897  2015    Peace  The Nobel Peace Prize 2015
# 399  1969    Peace  The Nobel Peace Prize 1969
# 283  1954    Peace  The Nobel Peace Prize 1954
# 558  1985    Peace  The Nobel Peace Prize 1985
# 873  2013    Peace  The Nobel Peace Prize 2013
# 682  1997    Peace  The Nobel Peace Prize 1997
#
#                                             motivation prize_share  \
# 788  "for their efforts to create economic and soci...         1/2
# 24                                                 NaN         1/1
# 215                                                NaN         1/1
# 479                                                NaN         1/1
# 897  "for its decisive contribution to the building...         1/1
# ...

# %% [markdown]
# ### Who were the oldest and youngest winners?
#
# **Challenge**:
# * What are the names of the youngest and oldest Nobel laureate?
# * What did they win the prize for?
# * What is the average age of a winner?
# * 75% of laureates are younger than what age when they receive the prize?
# * Use Seaborn to [create histogram](https://seaborn.pydata.org/generated/seaborn.histplot.html) to visualise the distribution of laureate age at the time of winning. Experiment with the number of `bins` to see how the visualisation changes.

# %% [markdown]
# ### Descriptive Statistics for the Laureate Age at Time of Award
#
# * Calculate the descriptive statistics for the age at the time of the award.
# * Then visualise the distribution in the form of a histogram using [Seaborn's .histplot() function](https://seaborn.pydata.org/generated/seaborn.histplot.html).
# * Experiment with the `bin` size. Try 10, 20, 30, and 50.

# %%
sns.histplot(
    df_data.drop(df_data[df_data.winning_age == 0].index),
    x="winning_age",
    bins=10
)
# Out:
# <Axes: xlabel='winning_age', ylabel='Count'>

# %%
sns.histplot(
    df_data.drop(df_data[df_data.winning_age == 0].index),
    x="winning_age",
    bins=20
)
# Out:
# <Axes: xlabel='winning_age', ylabel='Count'>

# %%
sns.histplot(
    df_data.drop(df_data[df_data.winning_age == 0].index),
    x="winning_age",
    bins=30
)
# Out:
# <Axes: xlabel='winning_age', ylabel='Count'>

# %%
sns.histplot(
    df_data.drop(df_data[df_data.winning_age == 0].index),
    x="winning_age",
    bins=50
)
# Out:
# <Axes: xlabel='winning_age', ylabel='Count'>

# %% [markdown]
# ### Age at Time of Award throughout History
#
# Are Nobel laureates being nominated later in life than before? Have the ages of laureates at the time of the award increased or decreased over time?
#
# **Challenge**
#
# * Use Seaborn to [create a .regplot](https://seaborn.pydata.org/generated/seaborn.regplot.html?highlight=regplot#seaborn.regplot) with a trendline.
# * Set the `lowess` parameter to `True` to show a moving average of the linear fit.
# * According to the best fit line, how old were Nobel laureates in the years 1900-1940 when they were awarded the prize?
# * According to the best fit line, what age would it predict for a Nobel laureate in 2020?

# %%
sns.regplot(
    data=df_data.drop(df_data[df_data.winning_age == 0].index),
    x="year",
    y="winning_age",
    lowess=True,
    scatter_kws={"alpha": 0.4},
    line_kws={"color": "red"},
)
# Out:
# <Axes: xlabel='year', ylabel='winning_age'>

# %% [markdown]
# ### Winning Age Across the Nobel Prize Categories
#
# How does the age of laureates vary by category?
#
# * Use Seaborn's [`.boxplot()`](https://seaborn.pydata.org/generated/seaborn.boxplot.html?highlight=boxplot#seaborn.boxplot) to show how the mean, quartiles, max, and minimum values vary across categories. Which category has the longest "whiskers"?
# * In which prize category are the average winners the oldest?
# * In which prize category are the average winners the youngest?

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.boxplot(
    data=df_data.drop(df_data[df_data.winning_age == 0].index),
    x="category",
    y="winning_age",
)
# Out:
# <Axes: xlabel='category', ylabel='winning_age'>

# %% [markdown]
# **Challenge**
# * Now use Seaborn's [`.lmplot()`](https://seaborn.pydata.org/generated/seaborn.lmplot.html?highlight=lmplot#seaborn.lmplot) and the `row` parameter to create 6 separate charts for each prize category. Again set `lowess` to `True`.
# * What are the winning age trends in each category?
# * Which category has the age trending up and which category has the age trending down?
# * Is this `.lmplot()` telling a different story from the `.boxplot()`?
# * Create another chart with Seaborn. This time use `.lmplot()` to put all 6 categories on the same chart using the `hue` parameter.

# %%
plt.figure(figsize=(12,4), dpi=200)

sns.lmplot(
    data=df_data.drop(df_data[df_data.winning_age == 0].index),
    x="year",
    y="winning_age",
    hue="category",
    lowess=True,
)
